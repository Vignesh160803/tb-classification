# %%
import matplotlib.pyplot as plt
import pathlib
import os
import shutil

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Dropout,Flatten
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
data_path = "/content/drive/MyDrive/TB_Chest_Radiography_Database"

# %%
data_dir = pathlib.Path(data_path)

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print(image_count)
# Out:
# 4200

# %%
data = os.listdir(data_path)

# %%
print(data)
# Out:
# ['Tuberculosis.metadata.xlsx', 'Normal.metadata.xlsx', 'README.md.txt', 'Normal', 'Tuberculosis']

# %%
img_types = {
    'Normal': list(data_dir.glob('Normal/*.png')),
    'Tuberculosis': list(data_dir.glob('Tuberculosis/*.png'))
}

# %%
import cv2
import PIL
import matplotlib.image as mpimg

# %%
def img_plot_original():
    fig, axs = plt.subplots(1,2)
    i = 0
    for key, value in img_types.items():
        img = mpimg.imread(str(img_types[key][3]))
        axs[i].imshow(img)
        axs[i].set_title(key)
        i+=1
img_plot_original()

# %%
labels = ['Normal','Tuberculosis']
size = [len(img_types['Normal']),len(img_types['Tuberculosis'])]
plt.pie(size,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x79366621a230>,
#   <matplotlib.patches.Wedge at 0x79366621a140>],
#  [Text(-0.9526279098330698, 0.5500000594609756, 'Normal'),
#   Text(0.9526278840857079, -0.5500001040567061, 'Tuberculosis')])

# %%
os.mkdir('xray-test')

# %%
test_path = "/content/xray-test"

# %%
data_test_dir = pathlib.Path(test_path)
